# %%
import pandas as pd
import numpy as np

years = list(range(1981, 2021))

df_calendar = pd.DataFrame({"Year_Key": years})

df_calendar["Decade"] = (df_calendar["Year_Key"] // 10*10).astype(str)+ "s"

df_calendar.to_csv("C:/Users/Viggo/Py/Learning Project/da_projects/sources/filipino-emigration/dim_calendar.csv", index=False)
# Out:
#     Year_Key Decade
# 0       1981  1980s
# 1       1982  1980s
# 2       1983  1980s
# 3       1984  1980s
# 4       1985  1980s
# 5       1986  1980s
# 6       1987  1980s
# 7       1988  1980s
# 8       1989  1980s
# 9       1990  1990s
# 10      1991  1990s
# 11      1992  1990s
# 12      1993  1990s
# 13      1994  1990s
# 14      1995  1990s
# 15      1996  1990s
# 16      1997  1990s
# 17      1998  1990s
# 18      1999  1990s
# 19      2000  2000s
# 20      2001  2000s
# 21      2002  2000s
# 22      2003  2000s
# 23      2004  2000s
# 24      2005  2000s
# 25      2006  2000s
# 26      2007  2000s
# 27      2008  2000s
# 28      2009  2000s
# 29      2010  2010s
# 30      2011  2010s
# 31      2012  2010s
# 32      2013  2010s
# 33      2014  2010s
# 34      2015  2010s
# 35      2016  2010s
# 36      2017  2010s
# 37      2018  2010s
# 38      2019  2010s
# 39      2020  2020s
